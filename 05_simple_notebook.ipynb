# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Kapitel 5: Einfaches Notebook\n",
    "\n",
    "Dies ist ein minimales Jupyter Notebook, das als Demonstration für die automatische Ausführung in Jupyter Book v2 dient."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 0,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Ein einfacher Python-Code\n",
    "def berechne_quadrat(x):\n",
    "    return x ** 2\n",
    "\n",
    "ergebnis = berechne_quadrat(12)\n",
    "print(f\"Das Ergebnis ist: {ergebnis}\")"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "pyproject_format_version": 1
}
