# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Mein erstes Notebook für Google Colab\n",
    "Hier testen wir, ob die Rakete jetzt die Colab-Option anzeigt!"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 5
}
